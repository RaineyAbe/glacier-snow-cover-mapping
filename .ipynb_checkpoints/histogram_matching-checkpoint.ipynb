# %% [markdown]
# # Notebook to correct radiometry in Planet imagery using SciKit histogram matching
#
# Rainey Aberle
#
# Summer 2022

# %%
import os
import glob
import numpy as np
import rasterio as rio
import matplotlib.pyplot as plt
from skimage.exposure import match_histograms

# path to Planet images
im_path = '/Users/raineyaberle/Research/PhD/Wolverine/imagery/Planet/2021-04-20_2021-08-25/PSScene4Band/'
out_path = im_path+'../im_histograms/'

# %%
# -----Grab image file names
ims = os.chdir(im_path) # change directory
im_names = glob.glob('*SR_clip.tif') # load all .tif file names
im_names.sort() # sort file names by date
im_names
# Out:
# ['20210421_165658_0f21_3B_AnalyticMS_SR_clip.tif',
#  '20210421_165659_0f21_3B_AnalyticMS_SR_clip.tif',
#  '20210421_165700_0f21_3B_AnalyticMS_SR_clip.tif',
#  '20210421_202734_37_2423_3B_AnalyticMS_SR_clip.tif',
#  '20210421_211433_53_2254_3B_AnalyticMS_SR_clip.tif',
#  '20210421_211435_88_2254_3B_AnalyticMS_SR_clip.tif',
#  '20210422_213334_99_105d_3B_AnalyticMS_SR_clip.tif',
#  '20210423_170029_1053_3B_AnalyticMS_SR_clip.tif',
#  '20210423_170030_1053_3B_AnalyticMS_SR_clip.tif',
#  '20210423_170031_1053_3B_AnalyticMS_SR_clip.tif',
#  '20210423_170031_1_1053_3B_AnalyticMS_SR_clip.tif',
#  '20210423_202540_54_241a_3B_AnalyticMS_SR_clip.tif',
#  '20210424_202443_93_2431_3B_AnalyticMS_SR_clip.tif',
#  '20210425_165654_1050_3B_AnalyticMS_SR_clip.tif',
#  '20210425_165655_1050_3B_AnalyticMS_SR_clip.tif',
#  '20210425_165656_1050_3B_AnalyticMS_SR_clip.tif',
#  '20210425_165657_1050_3B_AnalyticMS_SR_clip.tif',
#  '20210425_211425_74_2406_3B_AnalyticMS_SR_clip.tif',
#  '20210425_211428_03_2406_3B_AnalyticMS_SR_clip.tif',
#  '20210426_170327_0f3c_3B_AnalyticMS_SR_clip.tif',
#  '20210426_170328_0f3c_3B_AnalyticMS_SR_clip.tif',
#  '20210426_170329_0f3c_3B_AnalyticMS_SR_clip.tif',
#  '20210426_203015_80_2262_3B_AnalyticMS_SR_clip.tif',
#  '20210426_203018_09_2262_3B_AnalyticMS_SR_clip.tif',
#  '20210426_203130_64_2251_3B_AnalyticMS_SR_clip.tif',
#  '20210426_203132_93_2251_3B_AnalyticMS_SR_clip.tif',
#  '20210427_194054_25_106d_3B_AnalyticMS_SR_clip.tif',
#  '20210427_194055_78_106d_3B_AnalyticMS_SR_clip.tif',
#  '20210429_170034_1048_3B_AnalyticMS_SR_clip.tif',
#  '20210501_202300_20_2463_3B_AnalyticMS_SR_clip.tif',
#  '20210501_202302_55_2463_3B_AnalyticMS_SR_clip.tif',
#  '20210501_211757_67_227a_3B_AnalyticMS_SR_clip.tif',
#  '20210501_211800_15_227a_3B_AnalyticMS_SR_clip.tif',
#  '20210507_165515_100d_3B_AnalyticMS_SR_clip.tif',
#  '20210507_165516_100d_3B_AnalyticMS_SR_clip.tif',
#  '20210507_165517_1_100d_3B_AnalyticMS_SR_clip.tif',
#  '20210507_170008_1054_3B_AnalyticMS_SR_clip.tif',
#  '20210517_202034_50_2206_3B_AnalyticMS_SR_clip.tif',
#  '20210517_202036_71_2206_3B_AnalyticMS_SR_clip.tif',
#  '20210518_211339_01_2401_3B_AnalyticMS_SR_clip.tif',
#  '20210518_211341_30_2401_3B_AnalyticMS_SR_clip.tif',
#  '20210524_165518_104b_3B_AnalyticMS_SR_clip.tif',
#  '20210524_165519_104b_3B_AnalyticMS_SR_clip.tif',
#  '20210524_165520_104b_3B_AnalyticMS_SR_clip.tif',
#  '20210605_165245_0f21_3B_AnalyticMS_SR_clip.tif',
#  '20210605_165245_1_0f21_3B_AnalyticMS_SR_clip.tif',
#  '20210605_202114_48_222b_3B_AnalyticMS_SR_clip.tif',
#  '20210605_202116_69_222b_3B_AnalyticMS_SR_clip.tif',
#  '20210605_202404_27_2431_3B_AnalyticMS_SR_clip.tif',
#  '20210606_201944_58_2463_3B_AnalyticMS_SR_clip.tif',
#  '20210606_201946_88_2463_3B_AnalyticMS_SR_clip.tif',
#  '20210606_202719_80_2428_3B_AnalyticMS_SR_clip.tif',
#  '20210606_202722_10_2428_3B_AnalyticMS_SR_clip.tif',
#  '20210611_165002_104b_3B_AnalyticMS_SR_clip.tif',
#  '20210611_165003_104b_3B_AnalyticMS_SR_clip.tif',
#  '20210611_165004_104b_3B_AnalyticMS_SR_clip.tif',
#  '20210611_193902_91_106e_3B_AnalyticMS_SR_clip.tif',
#  '20210611_193904_93_106e_3B_AnalyticMS_SR_clip.tif',
#  '20210611_205334_1011_3B_AnalyticMS_SR_clip.tif',
#  '20210612_210953_21_227a_3B_AnalyticMS_SR_clip.tif',
#  '20210612_210955_70_227a_3B_AnalyticMS_SR_clip.tif',
#  '20210613_193952_72_106c_3B_AnalyticMS_SR_clip.tif',
#  '20210613_193954_72_106c_3B_AnalyticMS_SR_clip.tif',
#  '20210613_202526_75_245d_3B_AnalyticMS_SR_clip.tif',
#  '20210613_202529_05_245d_3B_AnalyticMS_SR_clip.tif',
#  '20210614_164758_0f49_3B_AnalyticMS_SR_clip.tif',
#  '20210614_164759_0f49_3B_AnalyticMS_SR_clip.tif',
#  '20210614_164800_0f49_3B_AnalyticMS_SR_clip.tif',
#  '20210614_164801_0f49_3B_AnalyticMS_SR_clip.tif',
#  '20210614_205247_1025_3B_AnalyticMS_SR_clip.tif',
#  '20210615_202553_97_245f_3B_AnalyticMS_SR_clip.tif',
#  '20210615_202556_27_245f_3B_AnalyticMS_SR_clip.tif',
#  '20210615_202558_58_245f_3B_AnalyticMS_SR_clip.tif',
#  '20210615_211616_96_2426_3B_AnalyticMS_SR_clip.tif',
#  '20210615_211619_25_2426_3B_AnalyticMS_SR_clip.tif',
#  '20210629_165001_1050_3B_AnalyticMS_SR_clip.tif',
#  '20210629_165002_1050_3B_AnalyticMS_SR_clip.tif',
#  '20210629_165003_1050_3B_AnalyticMS_SR_clip.tif',
#  '20210629_203040_14_2233_3B_AnalyticMS_SR_clip.tif',
#  '20210630_205214_1035_3B_AnalyticMS_SR_clip.tif',
#  '20210701_203408_83_2441_3B_AnalyticMS_SR_clip.tif',
#  '20210701_203411_12_2441_3B_AnalyticMS_SR_clip.tif',
#  '20210704_164734_0f49_3B_AnalyticMS_SR_clip.tif',
#  '20210704_204515_1040_3B_AnalyticMS_SR_clip.tif',
#  '20210704_204516_1040_3B_AnalyticMS_SR_clip.tif',
#  '20210704_204517_1040_3B_AnalyticMS_SR_clip.tif',
#  '20210704_204638_1013_3B_AnalyticMS_SR_clip.tif',
#  '20210704_204639_1013_3B_AnalyticMS_SR_clip.tif',
#  '20210704_204640_1013_3B_AnalyticMS_SR_clip.tif',
#  '20210714_204342_1025_3B_AnalyticMS_SR_clip.tif',
#  '20210714_204343_1025_3B_AnalyticMS_SR_clip.tif',
#  '20210714_204344_1025_3B_AnalyticMS_SR_clip.tif',
#  '20210715_204551_1035_3B_AnalyticMS_SR_clip.tif',
#  '20210715_204552_1035_3B_AnalyticMS_SR_clip.tif',
#  '20210715_204553_1035_3B_AnalyticMS_SR_clip.tif',
#  '20210715_211156_75_2402_3B_AnalyticMS_SR_clip.tif',
#  '20210715_211159_05_2402_3B_AnalyticMS_SR_clip.tif',
#  '20210716_202701_03_245d_3B_AnalyticMS_SR_clip.tif',
#  '20210716_202703_50_245d_3B_AnalyticMS_SR_clip.tif',
#  '20210717_203016_37_2262_3B_AnalyticMS_SR_clip.tif',
#  '20210717_213409_67_1057_3B_AnalyticMS_SR_clip.tif',
#  '20210717_213411_17_1057_3B_AnalyticMS_SR_clip.tif',
#  '20210717_213412_67_1057_3B_AnalyticMS_SR_clip.tif',
#  '20210718_204742_100a_3B_AnalyticMS_SR_clip.tif',
#  '20210718_204743_100a_3B_AnalyticMS_SR_clip.tif',
#  '20210718_204744_100a_3B_AnalyticMS_SR_clip.tif',
#  '20210718_213547_71_1066_3B_AnalyticMS_SR_clip.tif',
#  '20210718_213549_21_1066_3B_AnalyticMS_SR_clip.tif',
#  '20210718_213550_71_1066_3B_AnalyticMS_SR_clip.tif',
#  '20210719_205616_68_105c_3B_AnalyticMS_SR_clip.tif',
#  '20210726_164152_1053_3B_AnalyticMS_SR_clip.tif',
#  '20210726_164153_1053_3B_AnalyticMS_SR_clip.tif',
#  '20210726_202247_62_2436_3B_AnalyticMS_SR_clip.tif',
#  '20210726_204316_100c_3B_AnalyticMS_SR_clip.tif',
#  '20210726_204317_100c_3B_AnalyticMS_SR_clip.tif',
#  '20210726_204318_100c_3B_AnalyticMS_SR_clip.tif',
#  '20210731_201800_68_2212_3B_AnalyticMS_SR_clip.tif',
#  '20210731_201802_89_2212_3B_AnalyticMS_SR_clip.tif',
#  '20210731_204802_0f17_3B_AnalyticMS_SR_clip.tif',
#  '20210731_204803_0f17_3B_AnalyticMS_SR_clip.tif',
#  '20210731_204804_0f17_3B_AnalyticMS_SR_clip.tif',
#  '20210801_164620_104a_3B_AnalyticMS_SR_clip.tif',
#  '20210801_164621_104a_3B_AnalyticMS_SR_clip.tif',
#  '20210801_164622_104a_3B_AnalyticMS_SR_clip.tif',
#  '20210801_193327_08_106d_3B_AnalyticMS_SR_clip.tif',
#  '20210801_193328_61_106d_3B_AnalyticMS_SR_clip.tif',
#  '20210801_193330_13_106d_3B_AnalyticMS_SR_clip.tif',
#  '20210801_202254_00_2456_3B_AnalyticMS_SR_clip.tif',
#  '20210801_202256_48_2456_3B_AnalyticMS_SR_clip.tif',
#  '20210801_204541_1003_3B_AnalyticMS_SR_clip.tif',
#  '20210801_210819_89_240c_3B_AnalyticMS_SR_clip.tif',
#  '20210801_210822_19_240c_3B_AnalyticMS_SR_clip.tif',
#  '20210802_203624_62_225a_3B_AnalyticMS_SR_clip.tif',
#  '20210802_203626_91_225a_3B_AnalyticMS_SR_clip.tif',
#  '20210802_204541_1012_3B_AnalyticMS_SR_clip.tif',
#  '20210802_204542_1012_3B_AnalyticMS_SR_clip.tif',
#  '20210802_204543_1012_3B_AnalyticMS_SR_clip.tif',
#  '20210802_213634_72_1057_3B_AnalyticMS_SR_clip.tif',
#  '20210802_213636_22_1057_3B_AnalyticMS_SR_clip.tif',
#  '20210813_204649_1012_3B_AnalyticMS_SR_clip.tif',
#  '20210815_202053_12_2459_3B_AnalyticMS_SR_clip.tif',
#  '20210815_202055_57_2429_3B_AnalyticMS_SR_clip.tif',
#  '20210815_202055_60_2459_3B_AnalyticMS_SR_clip.tif',
#  '20210815_202058_05_2429_3B_AnalyticMS_SR_clip.tif',
#  '20210815_202830_37_225a_3B_AnalyticMS_SR_clip.tif',
#  '20210815_202832_67_225a_3B_AnalyticMS_SR_clip.tif',
#  '20210815_204453_1010_3B_AnalyticMS_SR_clip.tif',
#  '20210815_204454_1010_3B_AnalyticMS_SR_clip.tif',
#  '20210815_204455_1010_3B_AnalyticMS_SR_clip.tif',
#  '20210816_202316_11_242a_3B_AnalyticMS_SR_clip.tif',
#  '20210816_202318_59_242a_3B_AnalyticMS_SR_clip.tif',
#  '20210818_164255_104e_3B_AnalyticMS_SR_clip.tif',
#  '20210818_164256_104e_3B_AnalyticMS_SR_clip.tif',
#  '20210818_204909_1014_3B_AnalyticMS_SR_clip.tif',
#  '20210818_204910_1014_3B_AnalyticMS_SR_clip.tif',
#  '20210818_204911_1014_3B_AnalyticMS_SR_clip.tif',
#  '20210821_201828_26_2428_3B_AnalyticMS_SR_clip.tif',
#  '20210821_201830_73_2428_3B_AnalyticMS_SR_clip.tif',
#  '20210821_204640_1013_3B_AnalyticMS_SR_clip.tif']

# %%
# -----load 'correct' image
# load image
im1_name = im_names[1]
im1 = rio.open(im1_name)
# read image bands
im_scalar = 10000
b1 = im1.read(1) / im_scalar
g1 = im1.read(2) / im_scalar
r1 = im1.read(3) / im_scalar
nir1 = im1.read(4) / im_scalar
# define grid
im1_x = np.linspace(im1.bounds.left, im1.bounds.right, num=np.shape(b1)[1])
im1_y = np.linspace(im1.bounds.top, im1.bounds.bottom, num=np.shape(b1)[0])

# -----load 'incorrect' image
im2_name = im_names[3]
im2 = rio.open(im2_name)
# read image bands
b2 = im2.read(1) / im_scalar
g2 = im2.read(2) / im_scalar
r2 = im2.read(3) / im_scalar
nir2 = im2.read(4) / im_scalar
# define grid
im2_x = np.linspace(im2.bounds.left, im2.bounds.right, num=np.shape(b2)[1])
im2_y = np.linspace(im2.bounds.top, im2.bounds.bottom, num=np.shape(b2)[0])

# -----apply histogram matching to each band
b2_matched = match_histograms(b2, b1)
g2_matched = match_histograms(g2, g1)
r2_matched = match_histograms(r2, r1)
nir2_matched = match_histograms(nir2, nir1)

# %%
# -----plot RGB images and histograms
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(16,10), gridspec_kw={'height_ratios': [3,1]})
plt.rcParams.update({'font.size': 12, 'font.serif': 'Arial'})
# incorrect image
ax1.imshow(np.dstack([r2, g2, b2]),
            extent=(np.min(im2_x)/1000, np.max(im2_x/1000), np.min(im2_y)/1000, np.max(im2_y)/1000))
ax1.set_xlabel('Easting [km]')
ax1.set_ylabel('Northing [km]')
ax1.set_title('Incorrect image')
h1_nir = ax4.hist(nir2.flatten(), color='purple', bins=100, alpha=0.5, label='NIR')
h1_b = ax4.hist(b2.flatten(), color='blue', bins=100, alpha=0.5, label='blue')
h1_g = ax4.hist(g2.flatten(), color='green', bins=100, alpha=0.5, label='green')
h1_r = ax4.hist(r2.flatten(), color='red', bins=100, alpha=0.5, label='red')
ax4.set_xlabel('Surface reflectance')
ax4.set_ylabel('Pixel counts')
ax4.set_ylim(0,np.max([h1_nir[0][1:], h1_g[0][1:], h1_r[0][1:], h1_b[0][1:]])+5000)
ax4.grid()
ax3.legend(loc='right')
# reference image
ax2.imshow(np.dstack([r1, g1, b1]),
            extent=(np.min(im1_x)/1000, np.max(im1_x/1000), np.min(im1_y)/1000, np.max(im1_y)/1000))
ax2.set_xlabel('Easting [km]')
ax2.set_title('Reference image')
h2_nir = ax5.hist(nir1.flatten(), color='purple', bins=100, alpha=0.5, label='NIR')
h2_b = ax5.hist(b1.flatten(), color='blue', bins=100, alpha=0.5, label='blue')
h2_g = ax5.hist(g1.flatten(), color='green', bins=100, alpha=0.5, label='green')
h2_r = ax5.hist(r1.flatten(), color='red', bins=100, alpha=0.5, label='red')
ax5.set_xlabel('Surface reflectance')
ax5.set_ylim(0,np.max([h2_nir[0][1:], h2_g[0][1:], h2_r[0][1:], h2_b[0][1:]])+5000)
ax5.grid()
# histogram-matched image
ax3.imshow(np.dstack([r2_matched, g2_matched, b2_matched]),
            extent=(np.min(im2_x)/1000, np.max(im2_x/1000), np.min(im2_y)/1000, np.max(im2_y)/1000))
ax3.set_xlabel('Easting [km]')
ax3.set_title('Histogram-matched image')
h3_nir = ax6.hist(nir2_matched.flatten(), color='purple', bins=100, alpha=0.5, label='NIR')
h3_b = ax6.hist(b2_matched.flatten(), color='blue', bins=100, alpha=0.5, label='blue')
h3_g = ax6.hist(g2_matched.flatten(), color='green', bins=100, alpha=0.5, label='green')
h3_r = ax6.hist(r2_matched.flatten(), color='red', bins=100, alpha=0.5, label='red')
ax6.set_xlabel('Surface reflectance')
ax6.set_ylim(0,np.max([h3_nir[0][1:], h3_g[0][1:], h3_r[0][1:], h3_b[0][1:]])+5000)
ax6.grid()
fig.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
